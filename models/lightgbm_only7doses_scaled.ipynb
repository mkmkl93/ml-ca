# %%
import lightgbm as lgb
import itertools
import json
import numpy as np

from sklearn.metrics import mean_squared_error
from data_processor import read_data
import neptune

import warnings
warnings.filterwarnings("ignore")

print('Loading data...')
x_train, y_train = read_data('../data/only7doses/', 'train')
x_eval, y_eval = read_data('../data/only7doses/', 'eval')

neptune.init('kowson/OLN')

used_params = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Out:
# Loading data...
# Read dataset for train from file ../data/train.csv
# Read dataset for eval from file ../data/eval.csv

# %%
print('Preparing LightGBM datasets...')
lgb_train = lgb.Dataset(x_train, y_train)
lgb_eval = lgb.Dataset(x_eval, y_eval, reference=lgb_train)
# Out:
# Preparing LightGBM datasets...

# %%
TAGS = ['lightgbm', 'data_v3', 'one_dose', 'scaled', 'mape']

def neptune_monitor():
    def callback(env):
        for name, loss_name, loss_value, _ in env.evaluation_result_list:
            neptune.send_metric('{}_{}'.format(name, loss_name), x=env.iteration, y=loss_value)
    return callback

# %%
params_dict = {
    'boosting_type': ['gbdt', 'dart',],
    'objective': ['regression'],
    'metric': [['l2', 'l1']],
    'num_leaves': [25, 31, 40, 50, 100],
    'num_rounds': [70, 100, 150],
    'learning_rate': [0.05, 0.1, 0.2, 0.5],
    'bagging_fraction': [0.95],
    'bagging_freq': [5],
    # 'verbose': 1,
}

# %%
print("Training...")
try:
    with open('lgb_params_3.json') as data_file:
        used_params = json.load(data_file)
except (FileNotFoundError, json.JSONDecodeError): 
    used_params = []
keys, values = zip(*params_dict.items())
for v in itertools.product(*values):
    experiment_params = dict(zip(keys, v))
    if any(param_dict == experiment_params for param_dict in used_params):
        continue  # skip already computed
    neptune.create_experiment(
        name='LightGBM regressor on only 7 doses, scaled',
        params=experiment_params,
        tags=TAGS
    )
    params2 = experiment_params
    params2['verbose'] = 0
    gbm = lgb.train(
        params=params2, 
        train_set=lgb_train, 
        valid_sets=[lgb_train, lgb_eval],
        early_stopping_rounds=5,
        callbacks=[neptune_monitor()],
        verbose_eval=False,
    )
    # PREDICT AND EVAL
    y_pred = gbm.predict(x_eval, num_iteration=gbm.best_iteration)
    error = mean_squared_error(y_eval, y_pred) ** 0.5
    print("RMSE of prediction is: {}".format(error))
    neptune.log_text('rmse', str(error))
    mape = mean_absolute_percentage_error(y_eval, y_pred)
    print("MAPE of prediction is: {}".format(mape))
    neptune.log_text('mape', str(mape))
    neptune.stop()
    used_params.append(experiment_params)
    with open('lgb_params_3.json', 'w') as outfile:
        json.dump(used_params, outfile, sort_keys=True, indent=4)
# Out:
# Training...
# https://ui.neptune.ai/kowson/OLN/e/OLN-1907
# RMSE of prediction is: 0.09725304450768409
# MAPE of prediction is: 16.073833904841226
# https://ui.neptune.ai/kowson/OLN/e/OLN-1908
# RMSE of prediction is: 0.15994424304146987
# MAPE of prediction is: 23.727718210630293
# https://ui.neptune.ai/kowson/OLN/e/OLN-1909
# RMSE of prediction is: 0.0940469022253772
# MAPE of prediction is: 15.395072756832597
# https://ui.neptune.ai/kowson/OLN/e/OLN-1910
# RMSE of prediction is: 0.12482445247411078
# MAPE of prediction is: 18.519048925307533
# https://ui.neptune.ai/kowson/OLN/e/OLN-1911
# RMSE of prediction is: 0.09360455841406909
# MAPE of prediction is: 15.236472996669608
# https://ui.neptune.ai/kowson/OLN/e/OLN-1912
# RMSE of prediction is: 0.09961123673886772
# MAPE of prediction is: 15.425352841190875
# https://ui.neptune.ai/kowson/OLN/e/OLN-1913
# RMSE of prediction is: 0.0967707193191238
# MAPE of prediction is: 15.70381381617138
# https://ui.neptune.ai/kowson/OLN/e/OLN-1914
# RMSE of prediction is: 0.09431732306749659
# MAPE of prediction is: 15.278846894417317
# https://ui.neptune.ai/kowson/OLN/e/OLN-1915
# RMSE of prediction is: 0.09543994250799122
# MAPE of prediction is: 15.690223097389126
# https://ui.neptune.ai/kowson/OLN/e/OLN-1916
# RMSE of prediction is: 0.14802820953637746
# MAPE of prediction is: 21.871858882375435
# https://ui.neptune.ai/kowson/OLN/e/OLN-1917
# RMSE of prediction is: 0.09307274447330183
# MAPE of prediction is: 15.184237766612277
# https://ui.neptune.ai/kowson/OLN/e/OLN-1918
# RMSE of prediction is: 0.11184113162583563
# MAPE of prediction is: 16.871403126799386
# https://ui.neptune.ai/kowson/OLN/e/OLN-1919
# RMSE of prediction is: 0.09360454240754353
# MAPE of prediction is: 15.235472394396352
# https://ui.neptune.ai/kowson/OLN/e/OLN-1920
# RMSE of prediction is: 0.09637431028641966
# MAPE of prediction is: 15.20961585489436
# https://ui.neptune.ai/kowson/OLN/e/OLN-1921
# RMSE of prediction is: 0.0967707193191238
# MAPE of prediction is: 15.70381381617138
# https://ui.neptune.ai/kowson/OLN/e/OLN-1922
# RMSE of prediction is: 0.09375045675167828
# MAPE of prediction is: 15.216609250845298
# https://ui.neptune.ai/kowson/OLN/e/OLN-1923
# RMSE of prediction is: 0.09388252624633471
# MAPE of prediction is: 15.343706883792866
# https://ui.neptune.ai/kowson/OLN/e/OLN-1924
# RMSE of prediction is: 0.14044424987391538
# MAPE of prediction is: 20.736281019116444
# https://ui.neptune.ai/kowson/OLN/e/OLN-1925
# RMSE of prediction is: 0.09284825386628387
# MAPE of prediction is: 15.130977776850626
# https://ui.neptune.ai/kowson/OLN/e/OLN-1926
# RMSE of prediction is: 0.10679643893173524
# MAPE of prediction is: 16.25647641716861
# https://ui.neptune.ai/kowson/OLN/e/OLN-1927
# RMSE of prediction is: 0.09360454240754353
# MAPE of prediction is: 15.235472394396352
# https://ui.neptune.ai/kowson/OLN/e/OLN-1928
# RMSE of prediction is: 0.09508892580554364
# MAPE of prediction is: 15.05252211830961
# https://ui.neptune.ai/kowson/OLN/e/OLN-1929
# RMSE of prediction is: 0.0967707193191238
# MAPE of prediction is: 15.70381381617138
# https://ui.neptune.ai/kowson/OLN/e/OLN-1930
# RMSE of prediction is: 0.0933480190391507
# MAPE of prediction is: 15.193853372386759
# https://ui.neptune.ai/kowson/OLN/e/OLN-1931
# RMSE of prediction is: 0.09670259505896887
# MAPE of prediction is: 15.964494110631852
# https://ui.neptune.ai/kowson/OLN/e/OLN-1932
# RMSE of prediction is: 0.1595763158153337
# MAPE of prediction is: 23.70432847010274
# https://ui.neptune.ai/kowson/OLN/e/OLN-1933
# RMSE of prediction is: 0.09395494635097845
# MAPE of prediction is: 15.329563169399984
# https://ui.neptune.ai/kowson/OLN/e/OLN-1934
# RMSE of prediction is: 0.12434647234772125
# MAPE of prediction is: 18.41827667455645
# https://ui.neptune.ai/kowson/OLN/e/OLN-1935
# RMSE of prediction is: 0.09334065830745403
# MAPE of prediction is: 15.191303630041622
# https://ui.neptune.ai/kowson/OLN/e/OLN-1936
# RMSE of prediction is: 0.09955428125055754
# MAPE of prediction is: 15.397132038841315
# https://ui.neptune.ai/kowson/OLN/e/OLN-1937
# RMSE of prediction is: 0.09601815885406047
# MAPE of prediction is: 15.611067762138466
# https://ui.neptune.ai/kowson/OLN/e/OLN-1938
# RMSE of prediction is: 0.09440821459589348
# MAPE of prediction is: 15.331023049568952
# https://ui.neptune.ai/kowson/OLN/e/OLN-1939
# RMSE of prediction is: 0.0948948821891298
# MAPE of prediction is: 15.583173653048195
# https://ui.neptune.ai/kowson/OLN/e/OLN-1940
# RMSE of prediction is: 0.1475718103308158
# MAPE of prediction is: 21.81768497288636
# https://ui.neptune.ai/kowson/OLN/e/OLN-1941
# RMSE of prediction is: 0.09312073944219736
# MAPE of prediction is: 15.172171698805261
# https://ui.neptune.ai/kowson/OLN/e/OLN-1942
# RMSE of prediction is: 0.11138865985972125
# MAPE of prediction is: 16.780016806494405
# https://ui.neptune.ai/kowson/OLN/e/OLN-1943
# RMSE of prediction is: 0.09334065830745403
# MAPE of prediction is: 15.191303630041622
# https://ui.neptune.ai/kowson/OLN/e/OLN-1944
# RMSE of prediction is: 0.09620059775893933
# MAPE of prediction is: 15.128738156322704
# https://ui.neptune.ai/kowson/OLN/e/OLN-1945
# RMSE of prediction is: 0.09601815885406047
# MAPE of prediction is: 15.611067762138466
# https://ui.neptune.ai/kowson/OLN/e/OLN-1946
# RMSE of prediction is: 0.09402777504760264
# MAPE of prediction is: 15.29791332025301
# https://ui.neptune.ai/kowson/OLN/e/OLN-1947
# RMSE of prediction is: 0.09351815251764956
# MAPE of prediction is: 15.275313946895434
# https://ui.neptune.ai/kowson/OLN/e/OLN-1948
# RMSE of prediction is: 0.14004294512558044
# MAPE of prediction is: 20.67889473798675
# https://ui.neptune.ai/kowson/OLN/e/OLN-1949
# RMSE of prediction is: 0.09288097187336619
# MAPE of prediction is: 15.118695619536904
# https://ui.neptune.ai/kowson/OLN/e/OLN-1950
# RMSE of prediction is: 0.10629488401632695
# MAPE of prediction is: 16.149470298256883
# https://ui.neptune.ai/kowson/OLN/e/OLN-1951
# RMSE of prediction is: 0.09334065830745403
# MAPE of prediction is: 15.191303630041622
# https://ui.neptune.ai/kowson/OLN/e/OLN-1952
# RMSE of prediction is: 0.0947855861448278
# MAPE of prediction is: 14.98342576830398
# https://ui.neptune.ai/kowson/OLN/e/OLN-1953
# RMSE of prediction is: 0.09601815885406047
# MAPE of prediction is: 15.611067762138466
# https://ui.neptune.ai/kowson/OLN/e/OLN-1954
# RMSE of prediction is: 0.0937135144368645
# MAPE of prediction is: 15.241939499264138
# https://ui.neptune.ai/kowson/OLN/e/OLN-1955
# RMSE of prediction is: 0.09609235478401504
# MAPE of prediction is: 15.843779079792888
# https://ui.neptune.ai/kowson/OLN/e/OLN-1956
# RMSE of prediction is: 0.15906822871127177
# MAPE of prediction is: 23.632968411194312
# https://ui.neptune.ai/kowson/OLN/e/OLN-1957
# RMSE of prediction is: 0.09319339341556164
# MAPE of prediction is: 15.212321669777715
# https://ui.neptune.ai/kowson/OLN/e/OLN-1958
# RMSE of prediction is: 0.12400458099185949
# MAPE of prediction is: 18.35351200933504
# https://ui.neptune.ai/kowson/OLN/e/OLN-1959
# RMSE of prediction is: 0.09331349777582439
# MAPE of prediction is: 15.164661656094813
# https://ui.neptune.ai/kowson/OLN/e/OLN-1960
# RMSE of prediction is: 0.0991427396319481
# MAPE of prediction is: 15.346987532416613
# https://ui.neptune.ai/kowson/OLN/e/OLN-1961
# RMSE of prediction is: 0.09625299369127413
# MAPE of prediction is: 15.593010689788613
# https://ui.neptune.ai/kowson/OLN/e/OLN-1962
# RMSE of prediction is: 0.09453550210125153
# MAPE of prediction is: 15.325876993898083
# https://ui.neptune.ai/kowson/OLN/e/OLN-1963
# RMSE of prediction is: 0.09436782437416016
# MAPE of prediction is: 15.474124508922355
# https://ui.neptune.ai/kowson/OLN/e/OLN-1964
# RMSE of prediction is: 0.1471500747567962
# MAPE of prediction is: 21.748229963770534
# https://ui.neptune.ai/kowson/OLN/e/OLN-1965
# RMSE of prediction is: 0.09252010914248508
# MAPE of prediction is: 15.04924567592773
# https://ui.neptune.ai/kowson/OLN/e/OLN-1966
# RMSE of prediction is: 0.11109169339027522
# MAPE of prediction is: 16.708109373826964
# https://ui.neptune.ai/kowson/OLN/e/OLN-1967
# RMSE of prediction is: 0.09331349777582439
# MAPE of prediction is: 15.164661656094813
# https://ui.neptune.ai/kowson/OLN/e/OLN-1968
# RMSE of prediction is: 0.09591437707843985
# MAPE of prediction is: 15.09533160865068
# https://ui.neptune.ai/kowson/OLN/e/OLN-1969
# RMSE of prediction is: 0.09625299369127413
# MAPE of prediction is: 15.593010689788613
# https://ui.neptune.ai/kowson/OLN/e/OLN-1970
# RMSE of prediction is: 0.09414638458522076
# MAPE of prediction is: 15.27013204478817
# https://ui.neptune.ai/kowson/OLN/e/OLN-1971
# RMSE of prediction is: 0.09312163570992421
# MAPE of prediction is: 15.18247300897998
# https://ui.neptune.ai/kowson/OLN/e/OLN-1972
# RMSE of prediction is: 0.1395210601624704
# MAPE of prediction is: 20.594438881889577
# https://ui.neptune.ai/kowson/OLN/e/OLN-1973
# RMSE of prediction is: 0.09198060506248112
# MAPE of prediction is: 14.935840488324411
# https://ui.neptune.ai/kowson/OLN/e/OLN-1974
# RMSE of prediction is: 0.10605708876580103
# MAPE of prediction is: 16.101716331761743
# https://ui.neptune.ai/kowson/OLN/e/OLN-1975
# RMSE of prediction is: 0.09331349777582439
# MAPE of prediction is: 15.164661656094813
# https://ui.neptune.ai/kowson/OLN/e/OLN-1976
# RMSE of prediction is: 0.09468653143984493
# MAPE of prediction is: 14.965673927150947
# https://ui.neptune.ai/kowson/OLN/e/OLN-1977
# RMSE of prediction is: 0.09625299369127413
# MAPE of prediction is: 15.593010689788613
# https://ui.neptune.ai/kowson/OLN/e/OLN-1978
# RMSE of prediction is: 0.09383811829038992
# MAPE of prediction is: 15.188391253952505
# https://ui.neptune.ai/kowson/OLN/e/OLN-1979
# RMSE of prediction is: 0.09561858610780666
# MAPE of prediction is: 15.732482548271989
# https://ui.neptune.ai/kowson/OLN/e/OLN-1980
# RMSE of prediction is: 0.15886712635911862
# MAPE of prediction is: 23.61153328190315
# https://ui.neptune.ai/kowson/OLN/e/OLN-1981
# RMSE of prediction is: 0.0928279478548131
# MAPE of prediction is: 15.128474242038736
# https://ui.neptune.ai/kowson/OLN/e/OLN-1982
# RMSE of prediction is: 0.12343677676755553
# MAPE of prediction is: 18.278320207888225
# https://ui.neptune.ai/kowson/OLN/e/OLN-1983
# RMSE of prediction is: 0.09347778714703592
# MAPE of prediction is: 15.221781393324482
# https://ui.neptune.ai/kowson/OLN/e/OLN-1984
# RMSE of prediction is: 0.09890313674666625
# MAPE of prediction is: 15.328217748275586
# https://ui.neptune.ai/kowson/OLN/e/OLN-1985
# RMSE of prediction is: 0.09680399670060183
# MAPE of prediction is: 15.771755229096984
# https://ui.neptune.ai/kowson/OLN/e/OLN-1986
# RMSE of prediction is: 0.09514411740999223
# MAPE of prediction is: 15.458044786276604
# https://ui.neptune.ai/kowson/OLN/e/OLN-1987
# RMSE of prediction is: 0.0940885402089595
# MAPE of prediction is: 15.400533568478645
# https://ui.neptune.ai/kowson/OLN/e/OLN-1988
# RMSE of prediction is: 0.14682342155321723
# MAPE of prediction is: 21.699351566425587
# https://ui.neptune.ai/kowson/OLN/e/OLN-1989
# RMSE of prediction is: 0.09227350687454428
# MAPE of prediction is: 14.995690413326443
# https://ui.neptune.ai/kowson/OLN/e/OLN-1990
# RMSE of prediction is: 0.11048094280434796
# MAPE of prediction is: 16.608429656793717
# https://ui.neptune.ai/kowson/OLN/e/OLN-1991
# RMSE of prediction is: 0.09347778714703592
# MAPE of prediction is: 15.221781393324482
# https://ui.neptune.ai/kowson/OLN/e/OLN-1992
# RMSE of prediction is: 0.09581214449488851
# MAPE of prediction is: 15.08285130199246
# https://ui.neptune.ai/kowson/OLN/e/OLN-1993
# RMSE of prediction is: 0.09680399670060183
# MAPE of prediction is: 15.771755229096984
# https://ui.neptune.ai/kowson/OLN/e/OLN-1994
# RMSE of prediction is: 0.09475695745772178
# MAPE of prediction is: 15.374775352092849
# https://ui.neptune.ai/kowson/OLN/e/OLN-1995
# RMSE of prediction is: 0.09286134735245198
# MAPE of prediction is: 15.136517258081417
# https://ui.neptune.ai/kowson/OLN/e/OLN-1996
# RMSE of prediction is: 0.13919904771316702
# MAPE of prediction is: 20.551245365061018
# https://ui.neptune.ai/kowson/OLN/e/OLN-1997
# RMSE of prediction is: 0.09205599640650143
# MAPE of prediction is: 14.957692705162994
# https://ui.neptune.ai/kowson/OLN/e/OLN-1998
# RMSE of prediction is: 0.10543860099360794
# MAPE of prediction is: 15.999484929294782
# https://ui.neptune.ai/kowson/OLN/e/OLN-1999
# RMSE of prediction is: 0.09347778714703592
# MAPE of prediction is: 15.221781393324482
# https://ui.neptune.ai/kowson/OLN/e/OLN-2000
# RMSE of prediction is: 0.09457568564607871
# MAPE of prediction is: 14.942979619402635
# https://ui.neptune.ai/kowson/OLN/e/OLN-2001
# RMSE of prediction is: 0.09680399670060183
# MAPE of prediction is: 15.771755229096984
# https://ui.neptune.ai/kowson/OLN/e/OLN-2002
# RMSE of prediction is: 0.09423736066472928
# MAPE of prediction is: 15.32583954547198
# https://ui.neptune.ai/kowson/OLN/e/OLN-2003
# RMSE of prediction is: 0.09467121761128272
# MAPE of prediction is: 15.50400851900348
# https://ui.neptune.ai/kowson/OLN/e/OLN-2004
# RMSE of prediction is: 0.1578631942994412
# MAPE of prediction is: 23.48745282462447
# https://ui.neptune.ai/kowson/OLN/e/OLN-2005
# RMSE of prediction is: 0.0929647925815623
# MAPE of prediction is: 15.163008145078823
# https://ui.neptune.ai/kowson/OLN/e/OLN-2006
# RMSE of prediction is: 0.12289866995025685
# MAPE of prediction is: 18.198739534718545
# https://ui.neptune.ai/kowson/OLN/e/OLN-2007
# RMSE of prediction is: 0.09348236695291917
# MAPE of prediction is: 15.208792649785577
# https://ui.neptune.ai/kowson/OLN/e/OLN-2008
# RMSE of prediction is: 0.09853341678253792
# MAPE of prediction is: 15.23274910963816
# https://ui.neptune.ai/kowson/OLN/e/OLN-2009
# RMSE of prediction is: 0.09733533764781808
# MAPE of prediction is: 15.819893775890131
# https://ui.neptune.ai/kowson/OLN/e/OLN-2010
# RMSE of prediction is: 0.09649601606602762
# MAPE of prediction is: 15.624158104069155
# https://ui.neptune.ai/kowson/OLN/e/OLN-2011
# RMSE of prediction is: 0.09342037682926711
# MAPE of prediction is: 15.226945347101323
# https://ui.neptune.ai/kowson/OLN/e/OLN-2012
# RMSE of prediction is: 0.14583222334041146
# MAPE of prediction is: 21.564565990747564
# https://ui.neptune.ai/kowson/OLN/e/OLN-2013
# RMSE of prediction is: 0.09270571777623503
# MAPE of prediction is: 15.120877452827033
# https://ui.neptune.ai/kowson/OLN/e/OLN-2014
# RMSE of prediction is: 0.10989737141333404
# MAPE of prediction is: 16.517899639288622
# https://ui.neptune.ai/kowson/OLN/e/OLN-2015
# RMSE of prediction is: 0.09348236695291917
# MAPE of prediction is: 15.208792649785577
# https://ui.neptune.ai/kowson/OLN/e/OLN-2016
# RMSE of prediction is: 0.09556456398760783
# MAPE of prediction is: 15.040372221233852
# https://ui.neptune.ai/kowson/OLN/e/OLN-2017
# RMSE of prediction is: 0.09733533764781808
# MAPE of prediction is: 15.819893775890131
# https://ui.neptune.ai/kowson/OLN/e/OLN-2018
# RMSE of prediction is: 0.09596648695751203
# MAPE of prediction is: 15.551101804634454
# https://ui.neptune.ai/kowson/OLN/e/OLN-2019
# RMSE of prediction is: 0.09271118995448173
# MAPE of prediction is: 15.068458578408473
# https://ui.neptune.ai/kowson/OLN/e/OLN-2020
# RMSE of prediction is: 0.13839974289990425
# MAPE of prediction is: 20.431347512099283
# https://ui.neptune.ai/kowson/OLN/e/OLN-2021
# RMSE of prediction is: 0.09270571777623503
# MAPE of prediction is: 15.120877452827033
# https://ui.neptune.ai/kowson/OLN/e/OLN-2022
# RMSE of prediction is: 0.10500202621027126
# MAPE of prediction is: 15.909344007807388
# https://ui.neptune.ai/kowson/OLN/e/OLN-2023
# RMSE of prediction is: 0.09348236695291917
# MAPE of prediction is: 15.208792649785577
# https://ui.neptune.ai/kowson/OLN/e/OLN-2024
# RMSE of prediction is: 0.09449144041748715
# MAPE of prediction is: 14.913763823790916
# https://ui.neptune.ai/kowson/OLN/e/OLN-2025
# RMSE of prediction is: 0.09733533764781808
# MAPE of prediction is: 15.819893775890131
# https://ui.neptune.ai/kowson/OLN/e/OLN-2026
# RMSE of prediction is: 0.09511488099790408
# MAPE of prediction is: 15.380372889655414
