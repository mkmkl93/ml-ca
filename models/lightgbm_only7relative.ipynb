# %%
import lightgbm as lgb
import itertools
import json
import numpy as np
from sklearn.metrics import mean_squared_error
from data_processor import read_data
import neptune

import warnings
warnings.filterwarnings("ignore")

print('Loading data...')
x_train, y_train = read_data('../data/only7doses/', 'train')
x_eval, y_eval = read_data('../data/only7doses/', 'eval')

neptune.init('kowson/OLN')

used_params = []

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Out:
# Loading data...
# Read dataset for train from file ../data/train.csv
# Read dataset for eval from file ../data/eval.csv

# %%
print('Preparing LightGBM datasets...')
lgb_train = lgb.Dataset(x_train, y_train)
lgb_eval = lgb.Dataset(x_eval, y_eval, reference=lgb_train)
# Out:
# Preparing LightGBM datasets...

# %%
TAGS = ['lightgbm', 'data_v4', 'one_dose', 'scaled', 'relative', 'mape']

def neptune_monitor():
    def callback(env):
        for name, loss_name, loss_value, _ in env.evaluation_result_list:
            neptune.send_metric('{}_{}'.format(name, loss_name), x=env.iteration, y=loss_value)
    return callback

# %%
params_dict = {
    'boosting_type': ['gbdt', 'dart',],
    'objective': ['regression'],
    'metric': [['l2', 'l1']],
    'num_leaves': [20, 31, 40, 50, 100],
    'num_rounds': [70, 100, 150],
    'learning_rate': [0.05, 0.1, 0.2, 0.5],
    'bagging_fraction': [0.95],
    'bagging_freq': [5],
    # 'verbose': 1,
}

# %%
print("Training...")
try:
    with open('lgb_params_4.json') as data_file:
        used_params = json.load(data_file)
except (FileNotFoundError, json.JSONDecodeError): 
    used_params = []
keys, values = zip(*params_dict.items())
for v in itertools.product(*values):
    experiment_params = dict(zip(keys, v))
    if any(param_dict == experiment_params for param_dict in used_params):
        continue  # skip already computed
    neptune.create_experiment(
        name='LightGBM regressor on only 7 relative doses, scaled',
        params=experiment_params,
        tags=TAGS
    )
    params2 = experiment_params
    params2['verbose'] = 0
    gbm = lgb.train(
        params=params2, 
        train_set=lgb_train, 
        valid_sets=[lgb_train, lgb_eval],
        early_stopping_rounds=5,
        callbacks=[neptune_monitor()],
        verbose_eval=False,
    )
    # PREDICT AND EVAL
    y_pred = gbm.predict(x_eval, num_iteration=gbm.best_iteration)
    error = mean_squared_error(y_eval, y_pred) ** 0.5
    print("RMSE of prediction is: {}".format(error))
    mape = mean_absolute_percentage_error(y_eval, y_pred)
    print("MAPE of prediction is: {}".format(error))
    neptune.log_text('rmse', str(error))
    neptune.log_text('mape', str(mape))
    neptune.stop()
    used_params.append(experiment_params)
    with open('lgb_params_4.json', 'w') as outfile:
        json.dump(used_params, outfile, sort_keys=True, indent=4)
# Out:
# Training...
# https://ui.neptune.ai/kowson/OLN/e/OLN-1781
# RMSE of prediction is: 0.09463605402162119
# MAPE of prediction is: 0.09463605402162119
# https://ui.neptune.ai/kowson/OLN/e/OLN-1782
# RMSE of prediction is: 0.15930716956835891
# MAPE of prediction is: 0.15930716956835891
# https://ui.neptune.ai/kowson/OLN/e/OLN-1783
# RMSE of prediction is: 0.09320389029581905
# MAPE of prediction is: 0.09320389029581905
# https://ui.neptune.ai/kowson/OLN/e/OLN-1784
# RMSE of prediction is: 0.15811641667207527
# MAPE of prediction is: 0.15811641667207527
# https://ui.neptune.ai/kowson/OLN/e/OLN-1785
# RMSE of prediction is: 0.0924515217186242
# MAPE of prediction is: 0.0924515217186242
# https://ui.neptune.ai/kowson/OLN/e/OLN-1786
# RMSE of prediction is: 0.1575600326544668
# MAPE of prediction is: 0.1575600326544668
# https://ui.neptune.ai/kowson/OLN/e/OLN-1787
# RMSE of prediction is: 0.09191406272380562
# MAPE of prediction is: 0.09191406272380562
# https://ui.neptune.ai/kowson/OLN/e/OLN-1788
# RMSE of prediction is: 0.15726879551843526
# MAPE of prediction is: 0.15726879551843526
# https://ui.neptune.ai/kowson/OLN/e/OLN-1789
# RMSE of prediction is: 0.09047861197327009
# MAPE of prediction is: 0.09047861197327009
# https://ui.neptune.ai/kowson/OLN/e/OLN-1790
# RMSE of prediction is: 0.15593462183287185
# MAPE of prediction is: 0.15593462183287185
# https://ui.neptune.ai/kowson/OLN/e/OLN-1791
# RMSE of prediction is: 0.08982574125244766
# MAPE of prediction is: 0.08982574125244766
# https://ui.neptune.ai/kowson/OLN/e/OLN-1792
# RMSE of prediction is: 0.12274859404146522
# MAPE of prediction is: 0.12274859404146522
# https://ui.neptune.ai/kowson/OLN/e/OLN-1793
# RMSE of prediction is: 0.08930063163069495
# MAPE of prediction is: 0.08930063163069495
# https://ui.neptune.ai/kowson/OLN/e/OLN-1794
# RMSE of prediction is: 0.1217241033942116
# MAPE of prediction is: 0.1217241033942116
# https://ui.neptune.ai/kowson/OLN/e/OLN-1795
# RMSE of prediction is: 0.08876490007212824
# MAPE of prediction is: 0.08876490007212824
# https://ui.neptune.ai/kowson/OLN/e/OLN-1796
# RMSE of prediction is: 0.12110421991358772
# MAPE of prediction is: 0.12110421991358772
# https://ui.neptune.ai/kowson/OLN/e/OLN-1797
# RMSE of prediction is: 0.08860129465891764
# MAPE of prediction is: 0.08860129465891764
# https://ui.neptune.ai/kowson/OLN/e/OLN-1798
# RMSE of prediction is: 0.12060037956227988
# MAPE of prediction is: 0.12060037956227988
# https://ui.neptune.ai/kowson/OLN/e/OLN-1799
# RMSE of prediction is: 0.088314633631595
# MAPE of prediction is: 0.088314633631595
# https://ui.neptune.ai/kowson/OLN/e/OLN-1800
# RMSE of prediction is: 0.11963206774083937
# MAPE of prediction is: 0.11963206774083937
# https://ui.neptune.ai/kowson/OLN/e/OLN-1801
# RMSE of prediction is: 0.08864163423974071
# MAPE of prediction is: 0.08864163423974071
# https://ui.neptune.ai/kowson/OLN/e/OLN-1802
# RMSE of prediction is: 0.09566555256879433
# MAPE of prediction is: 0.09566555256879433
# https://ui.neptune.ai/kowson/OLN/e/OLN-1803
# RMSE of prediction is: 0.08876062951229508
# MAPE of prediction is: 0.08876062951229508
# https://ui.neptune.ai/kowson/OLN/e/OLN-1804
# RMSE of prediction is: 0.09510622832299584
# MAPE of prediction is: 0.09510622832299584
# https://ui.neptune.ai/kowson/OLN/e/OLN-1805
# RMSE of prediction is: 0.08934821693727348
# MAPE of prediction is: 0.08934821693727348
# https://ui.neptune.ai/kowson/OLN/e/OLN-1806
# RMSE of prediction is: 0.09510984950860049
# MAPE of prediction is: 0.09510984950860049
# https://ui.neptune.ai/kowson/OLN/e/OLN-1807
# RMSE of prediction is: 0.0892610061216409
# MAPE of prediction is: 0.0892610061216409
# https://ui.neptune.ai/kowson/OLN/e/OLN-1808
# RMSE of prediction is: 0.09455853556032848
# MAPE of prediction is: 0.09455853556032848
# https://ui.neptune.ai/kowson/OLN/e/OLN-1809
# RMSE of prediction is: 0.08976143030198927
# MAPE of prediction is: 0.08976143030198927
# https://ui.neptune.ai/kowson/OLN/e/OLN-1810
# RMSE of prediction is: 0.09497938799175422
# MAPE of prediction is: 0.09497938799175422
# https://ui.neptune.ai/kowson/OLN/e/OLN-1811
# RMSE of prediction is: 0.09105766260995753
# MAPE of prediction is: 0.09105766260995753
# https://ui.neptune.ai/kowson/OLN/e/OLN-1812
# RMSE of prediction is: 0.08973809580245218
# MAPE of prediction is: 0.08973809580245218
# https://ui.neptune.ai/kowson/OLN/e/OLN-1813
# RMSE of prediction is: 0.09195177044235768
# MAPE of prediction is: 0.09195177044235768
# https://ui.neptune.ai/kowson/OLN/e/OLN-1814
# RMSE of prediction is: 0.0897725650888721
# MAPE of prediction is: 0.0897725650888721
# https://ui.neptune.ai/kowson/OLN/e/OLN-1815
# RMSE of prediction is: 0.091839476860204
# MAPE of prediction is: 0.091839476860204
# https://ui.neptune.ai/kowson/OLN/e/OLN-1816
# RMSE of prediction is: 0.09061932779558984
# MAPE of prediction is: 0.09061932779558984
# https://ui.neptune.ai/kowson/OLN/e/OLN-1817
# RMSE of prediction is: 0.09190138087204944
# MAPE of prediction is: 0.09190138087204944
# https://ui.neptune.ai/kowson/OLN/e/OLN-1818
# RMSE of prediction is: 0.09089019750440623
# MAPE of prediction is: 0.09089019750440623
# https://ui.neptune.ai/kowson/OLN/e/OLN-1819
# RMSE of prediction is: 0.09424198155182754
# MAPE of prediction is: 0.09424198155182754
# https://ui.neptune.ai/kowson/OLN/e/OLN-1820
# RMSE of prediction is: 0.09325220151179413
# MAPE of prediction is: 0.09325220151179413
# https://ui.neptune.ai/kowson/OLN/e/OLN-1821
# RMSE of prediction is: 0.0917730489799952
# MAPE of prediction is: 0.0917730489799952
# https://ui.neptune.ai/kowson/OLN/e/OLN-1822
# RMSE of prediction is: 0.14710627406533175
# MAPE of prediction is: 0.14710627406533175
# https://ui.neptune.ai/kowson/OLN/e/OLN-1823
# RMSE of prediction is: 0.09062845055910655
# MAPE of prediction is: 0.09062845055910655
# https://ui.neptune.ai/kowson/OLN/e/OLN-1824
# RMSE of prediction is: 0.1458575640013157
# MAPE of prediction is: 0.1458575640013157
# https://ui.neptune.ai/kowson/OLN/e/OLN-1825
# RMSE of prediction is: 0.09015818390053132
# MAPE of prediction is: 0.09015818390053132
# https://ui.neptune.ai/kowson/OLN/e/OLN-1826
# RMSE of prediction is: 0.14530632299016116
# MAPE of prediction is: 0.14530632299016116
# https://ui.neptune.ai/kowson/OLN/e/OLN-1827
# RMSE of prediction is: 0.08978630493275058
# MAPE of prediction is: 0.08978630493275058
# https://ui.neptune.ai/kowson/OLN/e/OLN-1828
# RMSE of prediction is: 0.14485764596854708
# MAPE of prediction is: 0.14485764596854708
# https://ui.neptune.ai/kowson/OLN/e/OLN-1829
# RMSE of prediction is: 0.08886419458119207
# MAPE of prediction is: 0.08886419458119207
# https://ui.neptune.ai/kowson/OLN/e/OLN-1830
# RMSE of prediction is: 0.1435907260355311
# MAPE of prediction is: 0.1435907260355311
# https://ui.neptune.ai/kowson/OLN/e/OLN-1831
# RMSE of prediction is: 0.08868709007529962
# MAPE of prediction is: 0.08868709007529962
# https://ui.neptune.ai/kowson/OLN/e/OLN-1832
# RMSE of prediction is: 0.10945988686919783
# MAPE of prediction is: 0.10945988686919783
# https://ui.neptune.ai/kowson/OLN/e/OLN-1833
# RMSE of prediction is: 0.08841919854186381
# MAPE of prediction is: 0.08841919854186381
# https://ui.neptune.ai/kowson/OLN/e/OLN-1834
# RMSE of prediction is: 0.10828565079032207
# MAPE of prediction is: 0.10828565079032207
# https://ui.neptune.ai/kowson/OLN/e/OLN-1835
# RMSE of prediction is: 0.08810996267357814
# MAPE of prediction is: 0.08810996267357814
# https://ui.neptune.ai/kowson/OLN/e/OLN-1836
# RMSE of prediction is: 0.10759722886569525
# MAPE of prediction is: 0.10759722886569525
# https://ui.neptune.ai/kowson/OLN/e/OLN-1837
# RMSE of prediction is: 0.08844752919259416
# MAPE of prediction is: 0.08844752919259416
# https://ui.neptune.ai/kowson/OLN/e/OLN-1838
# RMSE of prediction is: 0.10724653090384945
# MAPE of prediction is: 0.10724653090384945
# https://ui.neptune.ai/kowson/OLN/e/OLN-1839
# RMSE of prediction is: 0.08827444147988378
# MAPE of prediction is: 0.08827444147988378
# https://ui.neptune.ai/kowson/OLN/e/OLN-1840
# RMSE of prediction is: 0.1062829352679053
# MAPE of prediction is: 0.1062829352679053
# https://ui.neptune.ai/kowson/OLN/e/OLN-1841
# RMSE of prediction is: 0.08861653086546926
# MAPE of prediction is: 0.08861653086546926
# https://ui.neptune.ai/kowson/OLN/e/OLN-1842
# RMSE of prediction is: 0.09236149802900077
# MAPE of prediction is: 0.09236149802900077
# https://ui.neptune.ai/kowson/OLN/e/OLN-1843
# RMSE of prediction is: 0.08876062951229508
# MAPE of prediction is: 0.08876062951229508
# https://ui.neptune.ai/kowson/OLN/e/OLN-1844
# RMSE of prediction is: 0.09166839317857237
# MAPE of prediction is: 0.09166839317857237
# https://ui.neptune.ai/kowson/OLN/e/OLN-1845
# RMSE of prediction is: 0.08934821693727348
# MAPE of prediction is: 0.08934821693727348
# https://ui.neptune.ai/kowson/OLN/e/OLN-1846
# RMSE of prediction is: 0.09151239240382034
# MAPE of prediction is: 0.09151239240382034
# https://ui.neptune.ai/kowson/OLN/e/OLN-1847
# RMSE of prediction is: 0.0892610061216409
# MAPE of prediction is: 0.0892610061216409
# https://ui.neptune.ai/kowson/OLN/e/OLN-1848
# RMSE of prediction is: 0.09124552090354258
# MAPE of prediction is: 0.09124552090354258
# https://ui.neptune.ai/kowson/OLN/e/OLN-1849
# RMSE of prediction is: 0.08976143030198927
# MAPE of prediction is: 0.08976143030198927
# https://ui.neptune.ai/kowson/OLN/e/OLN-1850
# RMSE of prediction is: 0.0917231530711027
# MAPE of prediction is: 0.0917231530711027
# https://ui.neptune.ai/kowson/OLN/e/OLN-1851
# RMSE of prediction is: 0.09105766260995753
# MAPE of prediction is: 0.09105766260995753
# https://ui.neptune.ai/kowson/OLN/e/OLN-1852
# RMSE of prediction is: 0.08912583519067166
# MAPE of prediction is: 0.08912583519067166
# https://ui.neptune.ai/kowson/OLN/e/OLN-1853
# RMSE of prediction is: 0.09195177044235768
# MAPE of prediction is: 0.09195177044235768
# https://ui.neptune.ai/kowson/OLN/e/OLN-1854
# RMSE of prediction is: 0.08950067898699353
# MAPE of prediction is: 0.08950067898699353
# https://ui.neptune.ai/kowson/OLN/e/OLN-1855
# RMSE of prediction is: 0.091839476860204
# MAPE of prediction is: 0.091839476860204
# https://ui.neptune.ai/kowson/OLN/e/OLN-1856
# RMSE of prediction is: 0.0903418476934575
# MAPE of prediction is: 0.0903418476934575
# https://ui.neptune.ai/kowson/OLN/e/OLN-1857
# RMSE of prediction is: 0.09190138087204944
# MAPE of prediction is: 0.09190138087204944
# https://ui.neptune.ai/kowson/OLN/e/OLN-1858
# RMSE of prediction is: 0.09028074592839161
# MAPE of prediction is: 0.09028074592839161
# https://ui.neptune.ai/kowson/OLN/e/OLN-1859
# RMSE of prediction is: 0.09424198155182754
# MAPE of prediction is: 0.09424198155182754
# https://ui.neptune.ai/kowson/OLN/e/OLN-1860
# RMSE of prediction is: 0.09265739291461048
# MAPE of prediction is: 0.09265739291461048
# https://ui.neptune.ai/kowson/OLN/e/OLN-1861
# RMSE of prediction is: 0.0894674043921762
# MAPE of prediction is: 0.0894674043921762
# https://ui.neptune.ai/kowson/OLN/e/OLN-1862
# RMSE of prediction is: 0.1390703284476727
# MAPE of prediction is: 0.1390703284476727
# https://ui.neptune.ai/kowson/OLN/e/OLN-1863
# RMSE of prediction is: 0.08874446997633956
# MAPE of prediction is: 0.08874446997633956
# https://ui.neptune.ai/kowson/OLN/e/OLN-1864
# RMSE of prediction is: 0.13787825640189827
# MAPE of prediction is: 0.13787825640189827
# https://ui.neptune.ai/kowson/OLN/e/OLN-1865
# RMSE of prediction is: 0.08855585166277505
# MAPE of prediction is: 0.08855585166277505
# https://ui.neptune.ai/kowson/OLN/e/OLN-1866
# RMSE of prediction is: 0.1373349023463999
# MAPE of prediction is: 0.1373349023463999
# https://ui.neptune.ai/kowson/OLN/e/OLN-1867
# RMSE of prediction is: 0.08844103669834735
# MAPE of prediction is: 0.08844103669834735
# https://ui.neptune.ai/kowson/OLN/e/OLN-1868
# RMSE of prediction is: 0.13698682454499164
# MAPE of prediction is: 0.13698682454499164
# https://ui.neptune.ai/kowson/OLN/e/OLN-1869
# RMSE of prediction is: 0.08812178483261134
# MAPE of prediction is: 0.08812178483261134
# https://ui.neptune.ai/kowson/OLN/e/OLN-1870
# RMSE of prediction is: 0.1357914297367552
# MAPE of prediction is: 0.1357914297367552
# https://ui.neptune.ai/kowson/OLN/e/OLN-1871
# RMSE of prediction is: 0.08816363479256062
# MAPE of prediction is: 0.08816363479256062
# https://ui.neptune.ai/kowson/OLN/e/OLN-1872
# RMSE of prediction is: 0.10390101010085773
# MAPE of prediction is: 0.10390101010085773
# https://ui.neptune.ai/kowson/OLN/e/OLN-1873
# RMSE of prediction is: 0.08841784737313987
# MAPE of prediction is: 0.08841784737313987
# https://ui.neptune.ai/kowson/OLN/e/OLN-1874
# RMSE of prediction is: 0.1028164042114498
# MAPE of prediction is: 0.1028164042114498
# https://ui.neptune.ai/kowson/OLN/e/OLN-1875
# RMSE of prediction is: 0.08810743671715883
# MAPE of prediction is: 0.08810743671715883
# https://ui.neptune.ai/kowson/OLN/e/OLN-1876
# RMSE of prediction is: 0.10234141033098867
# MAPE of prediction is: 0.10234141033098867
# https://ui.neptune.ai/kowson/OLN/e/OLN-1877
# RMSE of prediction is: 0.08844752919259416
# MAPE of prediction is: 0.08844752919259416
# https://ui.neptune.ai/kowson/OLN/e/OLN-1878
# RMSE of prediction is: 0.10206654627505655
# MAPE of prediction is: 0.10206654627505655
# https://ui.neptune.ai/kowson/OLN/e/OLN-1879
# RMSE of prediction is: 0.08827444147988378
# MAPE of prediction is: 0.08827444147988378
# https://ui.neptune.ai/kowson/OLN/e/OLN-1880
# RMSE of prediction is: 0.10134020142012792
# MAPE of prediction is: 0.10134020142012792
# https://ui.neptune.ai/kowson/OLN/e/OLN-1881
# RMSE of prediction is: 0.08861653086546926
# MAPE of prediction is: 0.08861653086546926
# https://ui.neptune.ai/kowson/OLN/e/OLN-1882
# RMSE of prediction is: 0.09080201083649787
# MAPE of prediction is: 0.09080201083649787
# https://ui.neptune.ai/kowson/OLN/e/OLN-1883
# RMSE of prediction is: 0.08876062951229508
# MAPE of prediction is: 0.08876062951229508
# https://ui.neptune.ai/kowson/OLN/e/OLN-1884
# RMSE of prediction is: 0.09049149284901867
# MAPE of prediction is: 0.09049149284901867
# https://ui.neptune.ai/kowson/OLN/e/OLN-1885
# RMSE of prediction is: 0.08934821693727348
# MAPE of prediction is: 0.08934821693727348
# https://ui.neptune.ai/kowson/OLN/e/OLN-1886
# RMSE of prediction is: 0.09033905648558087
# MAPE of prediction is: 0.09033905648558087
# https://ui.neptune.ai/kowson/OLN/e/OLN-1887
# RMSE of prediction is: 0.0892610061216409
# MAPE of prediction is: 0.0892610061216409
# https://ui.neptune.ai/kowson/OLN/e/OLN-1888
# RMSE of prediction is: 0.09010112084964679
# MAPE of prediction is: 0.09010112084964679
# https://ui.neptune.ai/kowson/OLN/e/OLN-1889
# RMSE of prediction is: 0.08976143030198927
# MAPE of prediction is: 0.08976143030198927
# https://ui.neptune.ai/kowson/OLN/e/OLN-1890
# RMSE of prediction is: 0.09059097549507723
# MAPE of prediction is: 0.09059097549507723
# https://ui.neptune.ai/kowson/OLN/e/OLN-1891
# RMSE of prediction is: 0.09105766260995753
# MAPE of prediction is: 0.09105766260995753
# https://ui.neptune.ai/kowson/OLN/e/OLN-1892
# RMSE of prediction is: 0.08877315098908936
# MAPE of prediction is: 0.08877315098908936
# https://ui.neptune.ai/kowson/OLN/e/OLN-1893
# RMSE of prediction is: 0.09195177044235768
# MAPE of prediction is: 0.09195177044235768
# https://ui.neptune.ai/kowson/OLN/e/OLN-1894
# RMSE of prediction is: 0.08894166496560395
# MAPE of prediction is: 0.08894166496560395
# https://ui.neptune.ai/kowson/OLN/e/OLN-1895
# RMSE of prediction is: 0.091839476860204
# MAPE of prediction is: 0.091839476860204
# https://ui.neptune.ai/kowson/OLN/e/OLN-1896
# RMSE of prediction is: 0.08959900607590658
# MAPE of prediction is: 0.08959900607590658
# https://ui.neptune.ai/kowson/OLN/e/OLN-1897
# RMSE of prediction is: 0.09190138087204944
# MAPE of prediction is: 0.09190138087204944
# https://ui.neptune.ai/kowson/OLN/e/OLN-1898
# RMSE of prediction is: 0.08989903470482345
# MAPE of prediction is: 0.08989903470482345
# https://ui.neptune.ai/kowson/OLN/e/OLN-1899
# RMSE of prediction is: 0.09424198155182754
# MAPE of prediction is: 0.09424198155182754
# https://ui.neptune.ai/kowson/OLN/e/OLN-1900
# RMSE of prediction is: 0.092075636502792
# MAPE of prediction is: 0.092075636502792
